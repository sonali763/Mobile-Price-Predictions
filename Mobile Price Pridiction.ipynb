# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset

df = pd.read_csv(r'C:\Users\Tanishq Khandelwal\Desktop\Suar ka kachra\Suar EDA\eda\data_mobile_price_range.csv')
#Return the first 5 rows of the DataFrame
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.rename(columns={'sc_h':'screen_height','sc_w':'screen_width',
                  'px_height':'pixel_height','px_width':'pixel_width',
                  'n_cores':'numberOfcores','four_g':'4g','three_g':'3g',
                  'int_memory':'internal_memory','fc':'front_camera',
                  'blue':'bluetooth','pc':'primary_camera','m_dep':'mobile_depth'} , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   battery_power    2000 non-null   int64
#  1   bluetooth        2000 non-null   int64
#  2   clock_speed      2000 non-null   float64
#  3   dual_sim         2000 non-null   int64
#  4   front_camera     2000 non-null   int64
#  5   4g               2000 non-null   int64
#  6   internal_memory  2000 non-null   int64
#  7   mobile_depth     2000 non-null   float64
#  8   mobile_wt        2000 non-null   int64
#  9   numberOfcores    2000 non-null   int64
#  10  primary_camera   2000 non-null   int64
#  11  pixel_height     2000 non-null   int64
#  12  pixel_width      2000 non-null   int64
#  13  ram              2000 non-null   int64
#  14  screen_height    2000 non-null   int64
#  15  screen_width     2000 non-null   int64
#  16  talk_time        2000 non-null   int64
# ...

# %%
#Description of the data
df.describe()
df.describe().T # transpose
# Out:
#                   count        mean          std    min      25%     50%  \
# battery_power    2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# bluetooth        2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed      2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim         2000.0     0.50950     0.500035    0.0     0.00     1.0
# front_camera     2000.0     4.30950     4.341444    0.0     1.00     3.0
# 4g               2000.0     0.52150     0.499662    0.0     0.00     1.0
# internal_memory  2000.0    32.04650    18.145715    2.0    16.00    32.0
# mobile_depth     2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt        2000.0   140.24900    35.399655   80.0   109.00   141.0
# numberOfcores    2000.0     4.52050     2.287837    1.0     3.00     4.0
# primary_camera   2000.0     9.91650     6.064315    0.0     5.00    10.0
# pixel_height     2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %%
df.isnull().sum()
# Out:
# battery_power      0
# bluetooth          0
# clock_speed        0
# dual_sim           0
# front_camera       0
# 4g                 0
# internal_memory    0
# mobile_depth       0
# mobile_wt          0
# numberOfcores      0
# primary_camera     0
# pixel_height       0
# pixel_width        0
# ram                0
# screen_height      0
# screen_width       0
# talk_time          0
# 3g                 0
# touch_screen       0
# wifi               0
# price_range        0
# dtype: int64

# %%
# Total phones with screen_width = 0
print(len(df[df.screen_width == 0]))
# Total phones with pixel_height = 0
print(len(df[df.pixel_height == 0]))
# Out:
# 180
# 2

# %%
#where ther is screen_width and pixel_height is zero ,assigning mean values
df['screen_width'][df[df.screen_width == 0].index] = df.screen_width.mean()
df['pixel_height'][df[df.pixel_height == 0].index] = df.pixel_height.mean()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\3745606125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['screen_width'][df[df.screen_width == 0].index] = df.screen_width.mean()
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\3745606125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pixel_height'][df[df.pixel_height == 0].index] = df.pixel_height.mean()

# %%
#checking whether there is duplicates or not
len(df[df.duplicated()])
# Out:
# 0

# %%
## Copying cleaned data
# df.to_csv('Cln.csv')

# %% [markdown]
# ## Univariate Analysis

# %%
#classes
sns.set()
price_plot=df['price_range'].value_counts().plot(kind='bar')
plt.xlabel('price_range')
plt.ylabel('Count')
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})
ax=sns.displot(df["battery_power"])
plt.show()

# %%
#anlysis of data by vizualisation
fig,ax=plt.subplots(figsize=(10,5))
sns.barplot(data=df,x='bluetooth',y='price_range',ax=ax)
# Out:
# <AxesSubplot: xlabel='bluetooth', ylabel='price_range'>

# %%
sns.countplot(data=df , x= df.dual_sim )
plt.show()

# %%
sns.countplot(data=df , x= df.touch_screen )
plt.show()

# %%
sns.distplot(df.numberOfcores , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\38479408.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.numberOfcores , hist=True , color='g' , kde=True )

# %%
sns.distplot(df.ram, hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\315803123.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.ram, hist=True , color='g' , kde=True )

# %%
sns.distplot(df.talk_time , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\2612715869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.talk_time , hist=True , color='g' , kde=True )

# %%
sns.distplot(df.mobile_wt , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\4055354197.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.mobile_wt , hist=True , color='g' , kde=True )

# %%
sns.distplot(df.internal_memory , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\3173103985.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.internal_memory , hist=True , color='g' , kde=True )

# %%
sns.distplot(df.primary_camera , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\2012712044.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.primary_camera , hist=True , color='g' , kde=True )

# %%
sns.distplot(df.front_camera , hist=True , color='g' , kde=True )
plt.show()
# Out:
# C:\Users\Tanishq Khandelwal\AppData\Local\Temp\ipykernel_31636\1087723323.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.front_camera , hist=True , color='g' , kde=True )

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ###### ram

# %%
df.plot(x='price_range',y='ram',kind='scatter')
plt.show()
# Out:
# c:\Users\Tanishq Khandelwal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ###### pixel_width

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='pixel_width', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='pixel_width', ax=axs[1])
plt.show()

# %% [markdown]
# There is not a continuous increase in pixel width as we move from Low cost to Very high cost. Mobiles with 'Medium cost' and 'High cost' has almost equal pixel width. so we can say that it would be a driving factor in deciding price_range.

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='pixel_height', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='pixel_height', ax=axs[1])
plt.show()

# %% [markdown]
# ###### FC (front camera megapixels)

# %%
df.plot(x='price_range',y='front_camera',kind='scatter')
plt.show()
# Out:
# c:\Users\Tanishq Khandelwal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ###### PC (Primary camera Megapixels)

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='numberOfcores', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='numberOfcores', ax=axs[1])
plt.show()

# %% [markdown]
# ###### mobile weight

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='mobile_wt', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='mobile_wt', ax=axs[1])
plt.show()

# %% [markdown]
# ###### screen_size

# %% [markdown]
# Let's convert screen_size from cm to inches, since in real life we use inches to tell a screen size.

# %%
# Defining new variable sc_size

df['sc_size'] = np.sqrt((df['screen_height']**2) + (df['screen_width']**2))
df['sc_size'] = round(df['sc_size']/2.54, 2)

# %%
fig, axs = plt.subplots(1,2, figsize=(15,5))
sns.kdeplot(data=df, x='sc_size', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range', y='sc_size', ax=axs[1])
plt.show()

# %%
# Let's drop screen_height and screen_width

df.drop(['screen_height', 'screen_width'], axis = 1, inplace = True)

# %%
binary_features = [ '4g', '3g']

# %%
# Plot of binary features against price range

for col in binary_features:
  fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (15, 6))

  df[col].value_counts().plot.pie (autopct='%1.1f%%', ax = ax1, shadow=True, labeldistance=None)
  ax1.set_title('Distribution by price range')
  ax1.legend(['Support', 'Does not Support'])
  sns.countplot(x = col, hue = 'price_range', data = df, ax = ax2, color = 'pink')
  ax2.set_title('Distribution by price range')
  ax2.set_xlabel(col)
  ax2.legend(['Low Cost', 'Medium Cost', 'High Cost', 'Very High Cost'])
  ax2.set_xticklabels(['Does not Support', 'Support'])

# %%
#  defining new variable for pixels

df['pixels'] = df['pixel_height']*df['pixel_width']
# Dropping px_height and px_width

df.drop(['pixel_height', 'pixel_width'], axis = 1, inplace = True)
# Checking for multi-collinearity

correlation = df.corr()
plt.figure(figsize = [20, 15])
sns.heatmap(correlation, cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot: >

# %%
# looking for outliers using box plot
plt.figure(figsize=(25,10))
for index,item in enumerate([i for i in df.describe().columns.to_list()] ):
  plt.subplot(5,5,index+1)
  sns.boxplot(df[item])
print("\n")

# %% [markdown]
# ### Conclusion

# %% [markdown]
# 1. From EDA we can see that here are mobile phones in 4 price ranges. The number of elements is almost similar.
# 2. half the devices have Bluetooth, and half don’t
# 3. there is a gradual increase in battery as the price range  increases
# 4. Ram has continuous increase with price range while moving  from Low cost to Very high cost
# 5. costly phones are lighter
# 6. RAM, battery power, pixels played more significant role in deciding the price range of mobile phone.
